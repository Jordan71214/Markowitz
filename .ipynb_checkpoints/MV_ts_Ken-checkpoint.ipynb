692125935, -0.00464846856798463, 0, -0.0128958410829249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)


u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)

l_plus = m.Array(m.Var, n)
for i in l_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

l_minus = m.Array(m.Var, n)
for i in l_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_plus = m.Array(m.Var, n)
for i in s_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_minus = m.Array(m.Var, n)
for i in s_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

# %%
for i in range(n):
    m.Maximize(P.item(i) * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i]))
    m.Minimize(s_plus[i] - s_minus[i])
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
    m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  3
#    Constants    :  0
#    Variables    :  33
#    Intermediates:  0
#    Connections  :  12
#    Equations    :  21
#    Residuals    :  21
#
#  Number of state variables:    33
#  Number of total equations: -  15
#  Number of slack variables: -  0
#  ---------------------------------------
#  Degrees of freedom       :    18
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.00 NLPi:    3 Dpth:    0 Lvs:    0 Obj: -2.00E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.015600000000000003 sec
#  Objective      :  -2.0006109980559676
#  Successful solution
#  ---------------------------------------------------

# %%
# LP and LM can not be exists at the same time so does SP and SM


print('LP', [x for x in l_plus])
print('LM', [x for x in l_minus])
print('SP', [x for x in s_plus])
print('SM', [x for x in s_minus])
# Out:
# LP [[1.0], [1.0], [1.0]]
# LM [[0.0], [0.0], [0.0]]
# SP [[0.0], [0.0], [0.0]]
# SM [[0.005005005005], [1.0], [1.0]]

# %%
'''
教授給的code第一段可行解, w_minus以 (SP - SM)表示, 加入w_plus, w_plus以 (LP - LM)
'''
assets_obs = np.array([
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)

# use APOPT to find a solition
m.options.solver = 1

u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# lp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# lm = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# sp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# sm = m.Array(m.Var, n, lb=0, ub=1, integer=True)

# p = m.Const(0.001)
# for i in p:
#     i.value = 0.001

l_plus = m.Array(m.Var, n)
for i in l_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

l_minus = m.Array(m.Var, n)
for i in l_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_plus = m.Array(m.Var, n)
for i in s_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_minus = m.Array(m.Var, n)
for i in s_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

# w_plus = m.Array(m.Var, n)
# for i in range(len(w_plus)):
#     w_plus[i].value = 0
#     w_plus[i].lower = 0.05*u[i]
#     w_plus[i].upper = 0.2*u[i]

# w_minus = m.Array(m.Var, n)
# for i in range(len(w_minus)):
#     w_minus[i].value = 0
#     w_minus[i].lower = 0.05*v[i]
#     w_minus[i].upper = 0.2*v[i]



for i in range(n):
    m.Maximize(P.item(i) * ((l_plus[i] - l_minus[i]) - (s_plus[i] - s_minus[i])))
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
#     m.Minimize((w_plus[i] - w_minus[i]) ** 2 * C.item(i, i) ** 2)
#     for j in range(n):
#         if i != j:
#             m.Minimize(C.item(i, j) * (w_plus[i] - w_minus[i]) * (w_plus[j] - w_minus[j]))
    m.Minimize(s_plus[i]-s_minus[i])
#     m.Minimize(0.0025 * l_plus[i] + 0.0025 * l_minus[i])
#     m.Minimize(p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i])


m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)

# m.Equation(m.sum(
#     [(w_plus[i] + 1 * w_minus[i] \
#       + p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i]) for i in
#      range(n)]) == 1)

# for i in range(n):
#     m.Equation(lp[i] + lm[i] <= 1)
#     m.Equation(sp[i] + sm[i] <= 1)
#     m.Equation(w_plus[i] == l_plus[i] - l_minus[i])
#     m.Equation(w_minus[i] == s_plus[i] - s_minus[i])
#     m.Equation(u[i] + v[i] == y[i])
#     m.Equation(u[i] + v[i] <= 1)

m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  4
#    Constants    :  0
#    Variables    :  58
#    Intermediates:  0
#    Connections  :  16
#    Equations    :  34
#    Residuals    :  34
#
#  Number of state variables:    58
#  Number of total equations: -  20
#  Number of slack variables: -  0
#  ---------------------------------------
#  Degrees of freedom       :    38
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.00 NLPi:    3 Dpth:    0 Lvs:    0 Obj: -4.00E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.01759999999999999 sec
#  Objective      :  -4.001221996111935
#  Successful solution
#  ---------------------------------------------------

# %%
print("l_plus", [i for i in l_plus])
print("l_minus", [i for i in l_minus])

print("s_plus", [i for i in s_plus])
print("s_minus", [i for i in s_minus])
# Out:
# l_plus [[1.0], [1.0], [1.0]]
# l_minus [[0.0], [0.0], [0.0]]
# s_plus [[0.0], [0.0], [0.0]]
# s_minus [[0.005005005005], [1.0], [1.0]]

# %%
'''
教授給的code第一段可行解, w_minus以 (SP - SM)表示, 移除w_plus
'''
assets_obs = np.array([
    [0.00907849579534513, -0.00695985093505983, 0.0084299761604594, 0.00460637330420661, -0.0166407210123416, -0.0308227697859888, -0.0159197895240186, -0.0127675605999023, 0.000901306956012888, 0, -0.00904983551991793, 0.00724640852076725, 0.00292891952088526, -0.0119951647586384, -0.00433543177644596, 0.00660971067348635, -0.00958692574332696, 0.0244688238460112, 0.0120134926488238, -0.00576626126438815, -0.00311873721265473, -0.0189194832461658, -0.0285997352356136, -0.108902370498538, -0.00996337555082483, -0.011395379703615, 0.0171757426191143, -0.00472689955760422, 0.0138546197303906, -0.017282441148748, 0.010248414491368, 0.0260626285757702, -0.00280576641150291, 0.00102118977472798, 0, -0.023232846722337, 0.0111674969191731, -0.0214051503199956, 0.0118034157248844, -0.0089052448121078, -0.0151096313917661, -0.00858374369139144, -0.00648650922960677, 0.00890814367013811, -0.00945059011685392, 0.00189727662279466, -0.00325468147354204, -0.0189228188421451, 0.00276472390648269, -0.000828614879616203, 0.0196996794662562, -0.000542005433322949, -0.00325821629540358, -0.0214411732222413, 0.00664638281604644, -0.00859326147298701, 0.00222469502211111, -0.00892863074430132, -0.0059030389262782, -0.00622173952725283, ],
    [0.00303785911242742, 0.00151547582990027, 0.0127974652583047, 0.0190092718209104, 0.0364946864301199, -0.00971090554568595, -0.0136678898182987, -0.00217154254694342, -0.00363651498288239, 0, -0.00291672801750322, 0.00364711784480473, 0.00773265466471527, -0.0290662641433834, 0.00395458691147439, -0.0111698804689666, 0.0513319004579947, 0.0269080669484678, -0.00741373647419926, -0.00140077843916497, 0.00487963349002651, -0.00115827415580574, -0.0159049272751082, 0.00164914589485562, -0.00164914589485567, -0.00733339421955797, -0.00118689660372341, 0.00213440895878598, 0.00756763572455059, 0.00843837240378185, 0.0207943441041438, 0.00956052963076143, 0.00474620545879126, -0.00045239700493063, 0, -0.00792650286859609, -0.0020450391166462, -0.0107647066423052, 0.0119018841383533, 0.011310615413212, -0.00609335250098918, -0.00408137712007475, -0.0128068063784102, 0.00779731980213844, -0.00228927653251101, -0.00344137074074704, -0.00114815814918597, -0.0066893107527231, 0.016761469094511, 0.0227331700639883, 0.00510375629970297, 0.00199266340696577, -0.00553933360593972, 0.00399085554260851, -0.020800099265282, -0.00702904793497261, 0.00363681652749544, -0.00500284917723943, -0.00022864764544903, -0.00939099877556102, ],
    [0.0231043683454177, 0.0417104885813702, -0.0095182158209761, 0.0160098290574834, -0.0172060014489138, -0.00660464724480478, -0.00301659353942568, -0.0133821948406982, 0.0121730048505591, 0, -0.00728600673093332, 0.0211041899519374, 0.0534389621555603, -0.00226500663085212, -0.00113443007061176, -0.00284171830902758, -0.0318037790537778, -0.00885222658735119, 0.00414079266603139, 0.0035356548323078, 0.00235017734495367, 0.00643465221077915, -0.00291971010333475, 0.0127834396256749, -0.0046296378987421, -0.00348634867943777, 0.00406622692125935, -0.00464846856798463, 0, -0.0128958410829249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)

# use APOPT to find a solition
m.options.solver = 1

u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# lp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# lm = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# sp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# sm = m.Array(m.Var, n, lb=0, ub=1, integer=True)

# p = m.Const(0.001)
# for i in p:
#     i.value = 0.001

l_plus = m.Array(m.Var, n)
for i in l_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

l_minus = m.Array(m.Var, n)
for i in l_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_plus = m.Array(m.Var, n)
for i in s_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_minus = m.Array(m.Var, n)
for i in s_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

# w_plus = m.Array(m.Var, n)
# for i in range(len(w_plus)):
#     w_plus[i].value = 0
#     w_plus[i].lower = 0.05*u[i]
#     w_plus[i].upper = 0.2*u[i]

# w_minus = m.Array(m.Var, n)
# for i in range(len(w_minus)):
#     w_minus[i].value = 0
#     w_minus[i].lower = 0.05*v[i]
#     w_minus[i].upper = 0.2*v[i]



for i in range(n):
    m.Maximize(P.item(i) * (-s_plus[i] + s_minus[i]))
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
#     m.Minimize((w_plus[i] - w_minus[i]) ** 2 * C.item(i, i) ** 2)
#     for j in range(n):
#         if i != j:
#             m.Minimize(C.item(i, j) * (w_plus[i] - w_minus[i]) * (w_plus[j] - w_minus[j]))
    m.Minimize(s_plus[i]-s_minus[i])
#     m.Minimize(0.0025 * l_plus[i] + 0.0025 * l_minus[i])
#     m.Minimize(p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i])



m.Equation(m.sum([(s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
# m.Equation(m.sum(
#     [(w_plus[i] + 1 * w_minus[i] \
#       + p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i]) for i in
#      range(n)]) == 1)

# for i in range(n):
#     m.Equation(lp[i] + lm[i] <= 1)
#     m.Equation(sp[i] + sm[i] <= 1)
#     m.Equation(w_plus[i] == l_plus[i] - l_minus[i])
#     m.Equation(w_minus[i] == s_plus[i] - s_minus[i])
#     m.Equation(u[i] + v[i] == y[i])
#     m.Equation(u[i] + v[i] <= 1)

m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  5
#    Constants    :  0
#    Variables    :  83
#    Intermediates:  0
#    Connections  :  20
#    Equations    :  47
#    Residuals    :  47
#
#  Number of state variables:    83
#  Number of total equations: -  25
#  Number of slack variables: -  0
#  ---------------------------------------
#  Degrees of freedom       :    58
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.00 NLPi:    4 Dpth:    0 Lvs:    0 Obj: -3.01E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.018600000000000005 sec
#  Objective      :  -3.006582081847495
#  Successful solution
#  ---------------------------------------------------

# %%
print("l_plus", [i for i in l_plus])
print("l_minus", [i for i in l_minus])

print("s_plus", [i for i in s_plus])
print("s_minus", [i for i in s_minus])
# Out:
# l_plus [[1.0], [1.0], [1.0]]
# l_minus [[1.0], [1.0], [1.0]]
# s_plus [[1.0], [0.0], [1.0]]
# s_minus [[0.0], [1.0], [0.009009009009]]

# %%
'''
    只修改 m.Minimize(s_plus[i]+s_minus[i]) -> m.Minimize(s_plus[i]-s_minus[i])
'''

assets_obs = np.array([
]).T
n = assets_obs.shape[1]

P = np.asmatrix(np.mean(assets_obs, axis=0))
# w = np.asmatrix(np.random.dirichlet(np.ones(n), size=1))
C = np.cov(assets_obs.T)

# use APOPT to find a solition
m.options.solver = 1


u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)
lp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
lm = m.Array(m.Var, n, lb=0, ub=1, integer=True)
sp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
sm = m.Array(m.Var, n, lb=0, ub=1, integer=True)

# p = m.Const(0.001)
# for i in p:
#     i.value = 0.001

l_plus = m.Array(m.Var, n)
for i in l_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

l_minus = m.Array(m.Var, n)
for i in l_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_plus = m.Array(m.Var, n)
for i in s_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_minus = m.Array(m.Var, n)
for i in s_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

# w_plus = m.Array(m.Var, n)
# for i in range(len(w_plus)):
#     w_plus[i].value = 0
#     w_plus[i].lower = 0.05*u[i]
#     w_plus[i].upper = 0.2*u[i]

# w_minus = m.Array(m.Var, n)
# for i in range(len(w_minus)):
#     w_minus[i].value = 0
#     w_minus[i].lower = 0.05*v[i]
#     w_minus[i].upper = 0.2*v[i]

# l_plus = m.Array(m.Var, n)
# for i in range(len(l_plus)):
#     l_plus[i].value = 0
#     l_plus[i].lower = 0*lp[i]
#     l_plus[i].upper = 1*lp[i]

# l_minus = m.Array(m.Var, n)
# for i in range(len(l_minus)):
#     l_minus[i].value = 0
#     l_minus[i].lower = 0*lm[i]
#     l_minus[i].upper = 1*lm[i]

# s_plus = m.Array(m.Var, n)
# for i in range(len(s_plus)):
#     s_plus[i].value = 0
#     s_plus[i].lower = 0*sp[i]
#     s_plus[i].upper = 1*sp[i]

# s_minus = m.Array(m.Var, n)
# for i in range(len(s_minus)):
#     s_minus[i].value = 0
#     s_minus[i].lower = 0*sm[i]
#     s_minus[i].upper = 1*sm[i]
    

for i in range(n):
    m.Maximize(P.item(i) * (l_plus[i] -s_plus[i]))
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
#     m.Minimize((w_plus[i] - w_minus[i]) ** 2 * C.item(i, i) ** 2)
#     for j in range(n):
#         if i != j:
#             m.Minimize(C.item(i, j) * (w_plus[i] - w_minus[i]) * (w_plus[j] - w_minus[j]))
    m.Minimize(s_plus[i]-s_minus[i])
#     m.Minimize(0.0025 * l_plus[i] + 0.0025 * l_minus[i])
#     m.Minimize(p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i])


m.Equation(m.sum([(l_plus[i] + l_minus[i] +s_plus[i] + s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)

# m.Equation(m.sum(
#     [(w_plus[i] + 1 * w_minus[i] \
#       + p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i]) for i in
#      range(n)]) == 1)

# for i in range(n):
#     m.Equation(lp[i] + lm[i] <= 1)
#     m.Equation(sp[i] + sm[i] <= 1)
#     m.Equation(w_plus[i] == l_plus[i] - l_minus[i])
#     m.Equation(w_minus[i] == s_plus[i] - s_minus[i])
#     m.Equation(u[i] + v[i] == y[i])
#     m.Equation(u[i] + v[i] <= 1)

m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  6
#    Constants    :  0
#    Variables    :  120
#    Intermediates:  0
#    Connections  :  24
#    Equations    :  60
#    Residuals    :  60
#
#  Number of state variables:    120
#  Number of total equations: -  30
#  Number of slack variables: -  0
#  ---------------------------------------
#  Degrees of freedom       :    90
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.00 NLPi:    2 Dpth:    0 Lvs:    0 Obj: -4.00E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.018199999999999994 sec
#  Objective      :  -4.004584079849493
#  Successful solution
#  ---------------------------------------------------

# %%
print("l_plus", [i for i in l_plus])
print("l_minus", [i for i in l_minus])
print("s_plus", [i for i in s_plus])
print("s_minus", [i for i in s_minus])
# Out:
# l_plus [[0.0], [0.0], [0.0]]
# l_minus [[0.0], [0.0], [0.0]]
# s_plus [[0.0], [0.0], [0.0]]
# s_minus [[0.333000333], [0.333000333], [0.333000333]]

# %%
'''
教授給的code第一段可行解, w_minus以 (SP - SM)表示, 加入w_plus, w_plus以 (LP - LM), add the weight ubound and lbound.
'''
assets_obs = np.array([
    [0.00907849579534513, -0.00695985093505983, 0.0084299761604594, 0.00460637330420661, -0.0166407210123416, -0.0308227697859888, -0.0159197895240186, -0.0127675605999023, 0.000901306956012888, 0, -0.00904983551991793, 0.00724640852076725, 0.00292891952088526, -0.0119951647586384, -0.00433543177644596, 0.00660971067348635, -0.00958692574332696, 0.0244688238460112, 0.0120134926488238, -0.00576626126438815, -0.00311873721265473, -0.0189194832461658, -0.0285997352356136, -0.108902370498538, -0.00996337555082483, -0.011395379703615, 0.0171757426191143, -0.00472689955760422, 0.0138546197303906, -0.017282441148748, 0.010248414491368, 0.0260626285757702, -0.00280576641150291, 0.00102118977472798, 0, -0.023232846722337, 0.0111674969191731, -0.0214051503199956, 0.0118034157248844, -0.0089052448121078, -0.0151096313917661, -0.00858374369139144, -0.00648650922960677, 0.00890814367013811, -0.00945059011685392, 0.00189727662279466, -0.00325468147354204, -0.0189228188421451, 0.00276472390648269, -0.000828614879616203, 0.0196996794662562, -0.000542005433322949, -0.00325821629540358, -0.0214411732222413, 0.00664638281604644, -0.00859326147298701, 0.00222469502211111, -0.00892863074430132, -0.0059030389262782, -0.00622173952725283, ],
    [0.00303785911242742, 0.00151547582990027, 0.0127974652583047, 0.0190092718209104, 0.0364946864301199, -0.00971090554568595, -0.0136678898182987, -0.00217154254694342, -0.00363651498288239, 0, -0.00291672801750322, 0.00364711784480473, 0.00773265466471527, -0.0290662641433834, 0.00395458691147439, -0.0111698804689666, 0.0513319004579947, 0.0269080669484678, -0.00741373647419926, -0.00140077843916497, 0.00487963349002651, -0.00115827415580574, -0.0159049272751082, 0.00164914589485562, -0.00164914589485567, -0.00733339421955797, -0.00118689660372341, 0.00213440895878598, 0.00756763572455059, 0.00843837240378185, 0.0207943441041438, 0.00956052963076143, 0.00474620545879126, -0.00045239700493063, 0, -0.00792650286859609, -0.0020450391166462, -0.0107647066423052, 0.0119018841383533, 0.011310615413212, -0.00609335250098918, -0.00408137712007475, -0.0128068063784102, 0.00779731980213844, -0.00228927653251101, -0.00344137074074704, -0.00114815814918597, -0.0066893107527231, 0.016761469094511, 0.0227331700639883, 0.00510375629970297, 0.00199266340696577, -0.00553933360593972, 0.00399085554260851, -0.020800099265282, -0.00702904793497261, 0.00363681652749544, -0.00500284917723943, -0.00022864764544903, -0.00939099877556102, ],
    [0.0231043683454177, 0.0417104885813702, -0.0095182158209761, 0.0160098290574834, -0.0172060014489138, -0.00660464724480478, -0.00301659353942568, -0.0133821948406982, 0.0121730048505591, 0, -0.00728600673093332, 0.0211041899519374, 0.0534389621555603, -0.00226500663085212, -0.00113443007061176, -0.00284171830902758, -0.0318037790537778, -0.00885222658735119, 0.00414079266603139, 0.0035356548323078, 0.00235017734495367, 0.00643465221077915, -0.00291971010333475, 0.0127834396256749, -0.0046296378987421, -0.00348634867943777, 0.00406622692125935, -0.00464846856798463, 0, -0.0128958410829249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)

# use APOPT to find a solition
m.options.solver = 1

u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# lp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# lm = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# sp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
# sm = m.Array(m.Var, n, lb=0, ub=1, integer=True)

# p = m.Const(0.001)
# for i in p:
#     i.value = 0.001

l_plus = m.Array(m.Var, n)
for i in l_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

l_minus = m.Array(m.Var, n)
for i in l_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_plus = m.Array(m.Var, n)
for i in s_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_minus = m.Array(m.Var, n)
for i in s_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

# w_plus = m.Array(m.Var, n)
# for i in range(len(w_plus)):
#     w_plus[i].value = 0
#     w_plus[i].lower = 0.05*u[i]
#     w_plus[i].upper = 0.2*u[i]

# w_minus = m.Array(m.Var, n)
# for i in range(len(w_minus)):
#     w_minus[i].value = 0
#     w_minus[i].lower = 0.05*v[i]
#     w_minus[i].upper = 0.2*v[i]



for i in range(n):
    m.Maximize(P.item(i) * ((l_plus[i] - l_minus[i]) - (s_plus[i] - s_minus[i])))
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
#     m.Minimize((w_plus[i] - w_minus[i]) ** 2 * C.item(i, i) ** 2)
#     for j in range(n):
#         if i != j:
#             m.Minimize(C.item(i, j) * (w_plus[i] - w_minus[i]) * (w_plus[j] - w_minus[j]))
    m.Minimize(s_plus[i]-s_minus[i])
#     m.Minimize(0.0025 * l_plus[i] + 0.0025 * l_minus[i])
#     m.Minimize(p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i])


m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
for i in range(n):
    #     m.Equation(0.05*u[i] <= l_plus[i] - l_minus[i] <= 0.2*u[i])
    #     m.Equation(0.05*v[i] <= s_plus[i] - s_minus[i] <= 0.2*v[i])
    m.Equation(0.05*u[i] <= l_plus[i] - l_minus[i])
    m.Equation(l_plus[i] - l_minus[i] <= 0.2*u[i])
    m.Equation(0.05*v[i] <= s_plus[i] - s_minus[i])
    m.Equation(s_plus[i] - s_minus[i] <= 0.2*v[i])
    
    
# m.Equation(m.sum(
#     [(w_plus[i] + 1 * w_minus[i] \
#       + p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i]) for i in
#      range(n)]) == 1)

# for i in range(n):
#     m.Equation(lp[i] + lm[i] <= 1)
#     m.Equation(sp[i] + sm[i] <= 1)
#     m.Equation(w_plus[i] == l_plus[i] - l_minus[i])
#     m.Equation(w_minus[i] == s_plus[i] - s_minus[i])
#     m.Equation(u[i] + v[i] == y[i])
#     m.Equation(u[i] + v[i] <= 1)

m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  7
#    Constants    :  0
#    Variables    :  157
#    Intermediates:  0
#    Connections  :  28
#    Equations    :  85
#    Residuals    :  85
#
#  Number of state variables:    157
#  Number of total equations: -  47
#  Number of slack variables: -  12
#  ---------------------------------------
#  Degrees of freedom       :    98
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 
    [0.0231043683454177, 0.0417104885813702, -0.0095182158209761, 0.0160098290574834, -0.0172060014489138, -0.00660464724480478, -0.00301659353942568, -0.0133821948406982, 0.0121730048505591, 0, -0.00728600673093332, 0.0211041899519374, 0.0534389621555603, -0.00226500663085212, -0.00113443007061176, -0.00284171830902758, -0.0318037790537778, -0.00885222658735119, 0.00414079266603139, 0.0035356548323078, 0.00235017734495367, 0.00643465221077915, -0.00291971010333475, 0.0127834396256749, -0.0046296378987421, -0.00348634867943777, 0.00406622692125935, -0.00464846856798463, 0, -0.0128958410829249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]

P = np.asmatrix(np.mean(assets_obs, axis=0))
# w = np.asmatrix(np.random.dirichlet(np.ones(n), size=1))
C = np.cov(assets_obs.T)

# use APOPT to find a solition
m.options.solver = 1



u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)
lp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
lm = m.Array(m.Var, n, lb=0, ub=1, integer=True)
sp = m.Array(m.Var, n, lb=0, ub=1, integer=True)
sm = m.Array(m.Var, n, lb=0, ub=1, integer=True)

# p = m.Const(0.001)
# for i in p:
#     i.value = 0.001

l_plus = m.Array(m.Var, n)
for i in l_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

l_minus = m.Array(m.Var, n)
for i in l_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_plus = m.Array(m.Var, n)
for i in s_plus:
    i.value = 0
    i.lower = 0
    i.upper = 1

s_minus = m.Array(m.Var, n)
for i in s_minus:
    i.value = 0
    i.lower = 0
    i.upper = 1

w_plus = m.Array(m.Var, n)
for i in range(len(w_plus)):
    w_plus[i].value = 0
    w_plus[i].lower = 0.05*u[i]
    w_plus[i].upper = 0.2*u[i]

w_minus = m.Array(m.Var, n)
for i in range(len(w_minus)):
    w_minus[i].value = 0
    w_minus[i].lower = 0.05*v[i]
    w_minus[i].upper = 0.2*v[i]

# l_plus = m.Array(m.Var, n)
# for i in range(len(l_plus)):
#     l_plus[i].value = 0
#     l_plus[i].lower = 0*lp[i]
#     l_plus[i].upper = 1*lp[i]

# l_minus = m.Array(m.Var, n)
# for i in range(len(l_minus)):
#     l_minus[i].value = 0
#     l_minus[i].lower = 0*lm[i]
#     l_minus[i].upper = 1*lm[i]

# s_plus = m.Array(m.Var, n)
# for i in range(len(s_plus)):
#     s_plus[i].value = 0
#     s_plus[i].lower = 0*sp[i]
#     s_plus[i].upper = 1*sp[i]

# s_minus = m.Array(m.Var, n)
# for i in range(len(s_minus)):
#     s_minus[i].value = 0
#     s_minus[i].lower = 0*sm[i]
#     s_minus[i].upper = 1*sm[i]
    

for i in range(n):
    m.Maximize(P.item(i) * (w_plus[i] - w_minus[i]))
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
#     m.Minimize((w_plus[i] - w_minus[i]) ** 2 * C.item(i, i) ** 2)
#     for j in range(n):
#         if i != j:
#             m.Minimize(C.item(i, j) * (w_plus[i] - w_minus[i]) * (w_plus[j] - w_minus[j]))
    m.Minimize(w_minus[i])
#     m.Minimize(0.0025 * l_plus[i] + 0.0025 * l_minus[i])
#     m.Minimize(p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i])


m.Equation(m.sum([(w_plus[i] + w_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)

# m.Equation(m.sum(
#     [(w_plus[i] + 1 * w_minus[i] \
#       + p[0] * l_plus[i] + p[1] * l_minus[i] + p[2] * s_plus[i] + p[3] * s_minus[i]) for i in
#      range(n)]) == 1)

# for i in range(n):
#     m.Equation(lp[i] + lm[i] <= 1)
#     m.Equation(sp[i] + sm[i] <= 1)
#     m.Equation(w_plus[i] == l_plus[i] - l_minus[i])
#     m.Equation(w_minus[i] == s_plus[i] - s_minus[i])
#     m.Equation(u[i] + v[i] == y[i])
#     m.Equation(u[i] + v[i] <= 1)
for i in range(n):
    #     m.Equation(0.05*u[i] <= l_plus[i] - l_minus[i] <= 0.2*u[i])
    #     m.Equation(0.05*v[i] <= s_plus[i] - s_minus[i] <= 0.2*v[i])
    m.Equation(0.05*u[i] <= l_plus[i] - l_minus[i])
    m.Equation(l_plus[i] - l_minus[i] <= 0.2*u[i])
    m.Equation(0.05*v[i] <= s_plus[i] - s_minus[i])
    m.Equation(s_plus[i] - s_minus[i] <= 0.2*v[i])
    
m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  8
#    Constants    :  0
#    Variables    :  212
#    Intermediates:  0
#    Connections  :  32
#    Equations    :  110
#    Residuals    :  110
#
#  Number of state variables:    212
#  Number of total equations: -  64
#  Number of slack variables: -  24
#  ---------------------------------------
#  Degrees of freedom       :    124
#
#  Number of bound variables: -  6
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I: -9 Tm:      0.21 NLPi:  251 Dpth:    0 Lvs:    0 Obj:  0.00E+00 Gap:       NaN
#  Warning: no more possible trial points and no integer solution
#  Maximum iterations
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  
    [0.0231043683454177, 0.0417104885813702, -0.0095182158209761, 0.0160098290574834, -0.0172060014489138, -0.00660464724480478, -0.00301659353942568, -0.0133821948406982, 0.0121730048505591, 0, -0.00728600673093332, 0.0211041899519374, 0.0534389621555603, -0.00226500663085212, -0.00113443007061176, -0.00284171830902758, -0.0318037790537778, -0.00885222658735119, 0.00414079266603139, 0.0035356548323078, 0.00235017734495367, 0.00643465221077915, -0.00291971010333475, 0.0127834396256749, -0.0046296378987421, -0.00348634867943777, 0.00406622692125935, -0.00464846856798463, 0, -0.0128958410829249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)
m.options.solver = 1

u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)

l_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
l_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)

    
for i in range(n):
    m.Maximize(P.item(i) * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i]))
    m.Minimize(s_plus[i] - s_minus[i])
    m.Minimize( 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i])
    m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  11
#    Constants    :  0
#    Variables    :  245
#    Intermediates:  0
#    Connections  :  44
#    Equations    :  131
#    Residuals    :  131
#
#  Number of state variables:    245
#  Number of total equations: -  79
#  Number of slack variables: -  24
#  ---------------------------------------
#  Degrees of freedom       :    142
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.01 NLPi:    5 Dpth:    0 Lvs:    0 Obj: -5.21E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.024399999999999977 sec
#  Objective      :  -5.205844478217134
#  Successful solution
#  ---------------------------------------------------

# %%
print('LP', [x for x in l_plus])
print('LM', [x for x in l_minus])
print('SP', [x for x in s_plus])
print('SM', [x for x in s_minus])
# Out:
# LP [[1.0], [1.0], [1.0]]
# LM [[0.0], [0.0], [0.0]]
# SP [[2.5347460947e-19], [0.0], [0.0]]
# SM [[0.005005005005], [1.0], [1.0]]

# %%
LP = [1.0, 1.0, 1.0]
LM = [0.0, 0.0, 0.0]
SP = [0.0, 0.0, 0.0]
SM = [0.005005005005, 1.0, 1.0]
calc = 0
for i in range(n):
0.00464846856798463, 0, -0.0128958410829249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)
m.options.solver = 1

u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)

l_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
l_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)

    
for i in range(n):
    m.Minimize(s_plus[i] - s_minus[i]
               + 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i] 
               - (P.item(i) * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i])))
    m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
    
m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  14
#    Constants    :  0
#    Variables    :  278
#    Intermediates:  0
#    Connections  :  56
#    Equations    :  146
#    Residuals    :  146
#
#  Number of state variables:    278
#  Number of total equations: -  94
#  Number of slack variables: -  24
#  ---------------------------------------
#  Degrees of freedom       :    160
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.02 NLPi:   13 Dpth:    0 Lvs:    0 Obj: -7.21E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.039100000000000024 sec
#  Objective      :  -7.206455476273103
#  Successful solution
#  ---------------------------------------------------

# %%
print('LP', [x for x in l_plus])
print('LM', [x for x in l_minus])
print('SP', [x for x in s_plus])
print('SM', [x for x in s_minus])
# Out:
# LP [[1.0], [1.0], [1.0]]
# LM [[0.0], [0.0], [0.0]]
# SP [[0.0], [0.0], [0.0]]
# SM [[0.005005005005], [1.0], [1.0]]

# %%
# concat objective 
assets_obs = np.array([
    [0.00907849579534513, -0.00695985093505983, 0.0084299761604594, 0.00460637330420661, -0.0166407210123416, -0.0308227697859888, -0.0159197895240186, -0.0127675605999023, 0.000901306956012888, 0, -0.00904983551991793, 0.00724640852076725, 0.00292891952088526, -0.0119951647586384, -0.00433543177644596, 0.00660971067348635, -0.00958692574332696, 0.0244688238460112, 0.0120134926488238, -0.00576626126438815, -0.00311873721
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)
m.options.solver = 1

u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)

l_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
l_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)

    
for i in range(n):
    m.Minimize(s_plus[i] - s_minus[i]
               + (l_plus[i] - l_minus[i])**2 * C.item(i, i)**2
               + 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i] 
               - (P.item(i) * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i])))
    for j in range(n):
        if j != i:
            m.Minimize(C.item(i, j) 
                       * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i]) 
                       * (l_plus[j] - l_minus[j] - s_plus[j] + s_minus[j]))
    
    m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
    
m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  17
#    Constants    :  0
#    Variables    :  311
#    Intermediates:  0
#    Connections  :  68
#    Equations    :  167
#    Residuals    :  167
#
#  Number of state variables:    311
#  Number of total equations: -  109
#  Number of slack variables: -  24
#  ---------------------------------------
#  Degrees of freedom       :    178
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I:  0 Tm:      0.01 NLPi:    5 Dpth:    0 Lvs:    0 Obj: -9.21E+00 Gap:  0.00E+00
#  Successful solution
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.024400000000000033 sec
#  Objective      :  -9.20687422539457
#  Successful solution
#  ---------------------------------------------------

# %%
print('LP', [x for x in l_plus])
print('LM', [x for x in l_minus])
print('SP', [x for x in s_plus])
print('SM', [x for x in s_minus])
# Out:
# LP [[1.0], [1.0], [1.0]]
# LM [[0.0], [0.0], [0.0]]
# SP [[0.0], [0.0], [0.0]]
# SM [[0.005005005005], [1.0], [1.0]]

# %%
LP = [1.0, 1.0, 1.0]
LM = [0.0, 0.0, 0.0]
SP = [0.0, 0.0, 0.0]
SM = [0.005005005005, 1.0, 1.0]
calc = 0
for i in range(n):
    calc += LP[i] - LM[i] + SP[i] - SM[i] + 0.005*LP[i] + 0.005*LM[i] + 0.005*SP[i] + 0.005*SM[i]
print(calc)

WP = []
for i in range(n):
    WP.append(LP[i] - LM[i])
    

WM = []
for i in range(n):
    WM.append(SP[i] - SM[i])
print("WP", WP)
print("WM", WM)
# Out:
# 1.0200200200200251
# WP [1.0, 1.0, 1.0]
# WM [-0.005005005005, -1.0, -1.0]

# %%
import pandas as pd
import copy
from gekko import GEKKO
import numpy as np
import os

m = GEKKO(remote=False)
249, -0.00236267091597039, 0.0117579249936131, 0.020822036241863, 0.0136443276487771, 0, -0.0125001627642315, -0.00401031760615392, -0.00114876520387337, 0.0102916860365475, 0.00454030291878301, -0.0205956936720807, 0.0114943794257352, -0.0207859677598346, 0.0098694560184841, -0.0174829627803475, 0.00702990592825815, -0.00175284882741436, 0.0110498361865849, -0.00405680069561443, -0.00816331063916098, -0.0052832526765831, 0.0157667499714412, 0.018370206601749, -0.000568990058025087, -0.0247779890293721, -0.0117372239457254, 0.00647251450561752, -0.00176108058429767, -0.00944517057151865, 0.00414324357133459, ],
]).T
n = assets_obs.shape[1]
P = np.asmatrix(np.mean(assets_obs, axis=0))
C = np.cov(assets_obs.T)
u = m.Array(m.Var, n, lb=0, ub=1, integer=True)
v = m.Array(m.Var, n, lb=0, ub=1, integer=True)
y = m.Array(m.Var, n, lb=0, ub=1, integer=True)

l_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
l_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_plus = m.Array(m.Var,n,lb=0,ub=1, value=0)
s_minus = m.Array(m.Var,n,lb=0,ub=1, value=0)

    
for i in range(n):
    m.Minimize(s_plus[i] - s_minus[i]
               + (l_plus[i] - l_minus[i])**2 * C.item(i, i)**2
               + 0.001*l_plus[i] +0.001*l_minus[i]+ 0.001*s_plus[i]+0.001*s_minus[i] 
               - (P.item(i) * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i])))
    for j in range(n):
        if j != i:
            m.Minimize(C.item(i, j) 
                       * (l_plus[i] - l_minus[i] - s_plus[i] + s_minus[i]) 
                       * (l_plus[j] - l_minus[j] - s_plus[j] + s_minus[j]))
    
    m.Equation(m.sum([(l_plus[i] - l_minus[i] +s_plus[i] - s_minus[i]\
                  + 0.001 * l_plus[i] + 0.001 * l_minus[i] \
                  + 0.001 * s_plus[i] + 0.001 * s_minus[i]) \
                 for i in range(n)]) == 1)
    m.Equation(0.05*u[i] <= l_plus[i] - l_minus[i])
    m.Equation(l_plus[i] - l_minus[i] <= 0.02*u[i])
    m.Equation(0.05*v[i] <= s_plus[i] - s_minus[i])
    m.Equation(s_plus[i] - s_minus[i] <= 0.02*v[i])
    m.Equation(u[i] + v[i] <= 1)
m.solve(disp=True,debug=0)
# Out:
#  ----------------------------------------------------------------
#  APMonitor, Version 1.0.0
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :  23
#    Constants    :  0
#    Variables    :  407
#    Intermediates:  0
#    Connections  :  92
#    Equations    :  239
#    Residuals    :  239
#
#  Number of state variables:    407
#  Number of total equations: -  169
#  Number of slack variables: -  54
#  ---------------------------------------
#  Degrees of freedom       :    184
#
#  ----------------------------------------------
#  Steady State Optimization with APOPT Solver
#  ----------------------------------------------
# Iter:     1 I: -1 Tm:      0.25 NLPi:   61 Dpth:    0 Lvs:    0 Obj:  0.00E+00 Gap:       NaN
#  Warning: no more possible trial points and no integer solution
#  Maximum iterations
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :  0.2669 sec
#  Objective      :  -9.194874225408382
#  Unsuccessful with error code  1
#  ---------------------------------------------------
#
#  Creating file: infeasibilities.txt
#  Use command apm_get(server,app,'infeasibilities.txt') to retrieve file
#  @error: Solution Not Found

# %%
# set the LM and SM == 0, because the first portfolio does not have any securities
